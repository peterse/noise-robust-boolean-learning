# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

from mindreadingautobots.sequence_generators import make_datasets, data_io
from mindreadingautobots.entropy_and_bayesian import entropy
import time

import gspread
from google.oauth2.service_account import Credentials

# %%
# Path to your service account JSON file
SERVICE_ACCOUNT_FILE = "../velvety-tube-450516-r5-2dfa430c056c.json" 


# Define the scope (Google Sheets + Google Drive API)
SCOPES = [
    "https://www.googleapis.com/auth/spreadsheets",
    "https://www.googleapis.com/auth/drive.file",  # Allows access to files the service account has access to
    "https://www.googleapis.com/auth/drive.readonly"  # Read-only access to drive files
]
# Authenticate with Google
creds = Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

# Open the spreadsheet
SPREADSHEET_NAME = "sparse_parity_21_4"
spreadsheet = client.open(SPREADSHEET_NAME)

# %%
# Get names of all sheets
sheet_names = [sheet.title for sheet in spreadsheet.worksheets()]
name_to_idx = {}
for i, name in enumerate(sheet_names):
    name_to_idx[name] = i
print("Sheets in the spreadsheet:")
for name in sheet_names:
    print(f"  {name}")

# transformer_template = 'SAN_sparse_parity_k4_nbits21_n2000_bf{}_seed1234'
# rnn_template = 'RNN_sparse_majority_k5_nbits21_n2000_bf{}_seed1234'
# bf_vals = list(range(0, 50, 5))
bf_vals = [0, 1, 2, 5, 7.5, 10, 12.5, 15, 17.5, 20]
best_n = 1
df_dct = {
    "RNN": {}, 
    "SAN": {}
            }

best_dct = {
    "RNN": {"noiseless": [], "noisy": [], "train_acc": []}, 
    "SAN": {"noiseless": [], "noisy": [], "train_acc": []}
            }

for k in best_dct.keys():
    sheetname_template = '{}_sparse_parity_k4_nbits21_n5000_bf{}_seed1234'
    for bf in bf_vals:
        target = sheetname_template.format(k, bf)
        target_idx = name_to_idx.get(target)
        print("Loading:", target)
        if target_idx is None:
            raise ValueError(f"Sheet {target} not found.")
        sheet = spreadsheet.get_worksheet(target_idx)
        data = sheet.get_all_records()
        print(data)
        df = pd.DataFrame(data)
        df_dct[k][bf] = df
        best_noiseless = df.sort_values(by='val_acc', ascending=False).head(best_n)['noiseless_val_acc'].to_numpy()
        best_noisy = df.sort_values(by='val_acc', ascending=False).head(best_n)['val_acc'].to_numpy()
        best_train_acc = df.sort_values(by='val_acc', ascending=False).head(best_n)['train_acc'].to_numpy()
        best_dct[k]["noiseless"].append(best_noiseless)
        best_dct[k]["noisy"].append(best_noisy)
        best_dct[k]["train_acc"].append(best_train_acc)
# Out:
# Sheets in the spreadsheet:
#   SAN_sparse_parity_k4_nbits21_n5000_bf1_seed1234
#   SAN_sparse_parity_k4_nbits21_n5000_bf5_seed1234
#   RNN_sparse_parity_k4_nbits21_n5000_bf0_seed1234
#   RNN_sparse_parity_k4_nbits21_n5000_bf10_seed1234
#   RNN_sparse_parity_k4_nbits21_n5000_bf20_seed1234
#   SAN_sparse_parity_k4_nbits21_n5000_bf0_seed1234
#   SAN_sparse_parity_k4_nbits21_n5000_bf10_seed1234
#   SAN_sparse_parity_k4_nbits21_n5000_bf20_seed1234
#   RNN_sparse_parity_k4_nbits21_n5000_bf1_seed1234
#   RNN_sparse_parity_k4_nbits21_n5000_bf2_seed1234
#   RNN_sparse_parity_k4_nbits21_n5000_bf5_seed1234
#   SAN_sparse_parity_k4_nbits21_n5000_bf7.5_seed1234
#   SAN_sparse_parity_k4_nbits21_n5000_bf12.5_seed1234
#   SAN_sparse_parity_k4_nbits21_n5000_bf15_seed1234
#   SAN_sparse_parity_k4_nbits21_n5000_bf17.5_seed1234
#   RNN_sparse_parity_k4_nbits21_n5000_bf12.5_seed1234
#   RNN_sparse_parity_k4_nbits21_n5000_bf7.5_seed1234
#   RNN_sparse_parity_k4_nbits21_n5000_bf17.5_seed1234
#   RNN_sparse_parity_k4_nbits21_n5000_bf15_seed1234
#   SAN_sparse_parity_k4_nbits21_n5000_bf2_seed1234
# Loading: RNN_sparse_parity_k4_nbits21_n5000_bf0_seed1234
# [{'epoch': 937, 'train_loss': 0.004641886821, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1, 'lr': 0.001206, 'emb_size': 128, 'hidden_size': 32, 'dropout': 0.05, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 651, 'train_loss': 7.59e-06, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1, 'lr': 0.000796, 'emb_size': 64, 'hidden_size': 128, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 141, 'train_loss': 0.001199814818, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1, 'lr': 0.004229, 'emb_size': 64, 'hidden_size': 128, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 65, 'train_loss': 0.04795267004, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1, 'lr': 0.000796, 'emb_size': 32, 'hidden_size': 128, 'dropout': 0.1, 'depth': 1, 'cell_type': 'LSTM'}, {'epoch': 195, 'train_loss': 0.01194909651, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1, 'lr': 0.002782, 'emb_size': 64, 'hidden_size': 16, 'dropout': 0.05, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 861, 'train_loss': 0.001074523593, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1, 'lr': 0.001206, 'emb_size': 16, 'hidden_size': 128, 'dropout': 0.1, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 203, 'train_loss': 0.07340900865, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1, 'lr': 0.004229, 'emb_size': 64, 'hidden_size': 16, 'dropout': 0.1, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 169, 'train_loss': 0.0009514952943, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1, 'lr': 0.001832, 'emb_size': 32, 'hidden_size': 128, 'dropout': 0.1, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 64, 'train_loss': 0.002593039387, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1, 'lr': 0.001206, 'emb_size': 32, 'hidden_size': 64, 'dropout': 0.1, 'depth': 1, 'cell_type': 'LSTM'}, {'epoch': 78, 'train_loss': 0.004550464469, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1, 'lr': 0.000346, 'emb_size': 64, 'hidden_size': 128, 'dropout': 0.05, 'depth': 2, 'cell_type': 'LSTM'}, {'epoch': 303, 'train_loss': 0.006988376184, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1, 'lr': 0.001206, 'emb_size': 128, 'hidden_size': 32, 'dropout': 0.1, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 414, 'train_loss': 0.0145367565, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1, 'lr': 0.000525, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.05, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 98, 'train_loss': 0.004343079626, 'train_acc': 1, 'val_acc': 0.9999001597, 'noiseless_val_acc': 0.9999001597, 'lr': 0.004229, 'emb_size': 128, 'hidden_size': 64, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 369, 'train_loss': 0.003300813007, 'train_acc': 1, 'val_acc': 0.9998003195, 'noiseless_val_acc': 0.9998003195, 'lr': 0.001832, 'emb_size': 128, 'hidden_size': 128, 'dropout': 0.1, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 312, 'train_loss': 0.0005513869094, 'train_acc': 1, 'val_acc': 0.9997004792, 'noiseless_val_acc': 0.9997004792, 'lr': 0.000346, 'emb_size': 128, 'hidden_size': 128, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 740, 'train_loss': 2.62e-05, 'train_acc': 1, 'val_acc': 0.99610623, 'noiseless_val_acc': 0.99610623, 'lr': 0.000796, 'emb_size': 64, 'hidden_size': 64, 'dropout': 0.05, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 493, 'train_loss': 0.02907451183, 'train_acc': 1, 'val_acc': 0.9857228435, 'noiseless_val_acc': 0.9857228435, 'lr': 0.002782, 'emb_size': 16, 'hidden_size': 16, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 997, 'train_loss': 0.01917407208, 'train_acc': 0.9996019108, 'val_acc': 0.9072484026, 'noiseless_val_acc': 0.9072484026, 'lr': 0.001206, 'emb_size': 64, 'hidden_size': 64, 'dropout': 0.1, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 897, 'train_loss': 0.005564115722, 'train_acc': 0.9998009554, 'val_acc': 0.8833865815, 'noiseless_val_acc': 0.8833865815, 'lr': 0.000796, 'emb_size': 128, 'hidden_size': 32, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 593, 'train_ ...
# Loading: RNN_sparse_parity_k4_nbits21_n5000_bf1_seed1234
# [{'epoch': 1, 'train_loss': 0.7619366152, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.022516, 'emb_size': 64, 'hidden_size': 128, 'dropout': 0.1, 'depth': 6, 'cell_type': 'LSTM'}, {'epoch': 727, 'train_loss': 0.09456921349, 'train_acc': 0.9964171975, 'val_acc': 0.6181110224, 'noiseless_val_acc': 0.6262979233, 'final_train_acc': 0.9992038217, 'final_val_acc': 0.6075279553, 'final_noiseless_val_acc': 0.6196086262, 'lr': 0.000346, 'emb_size': 32, 'hidden_size': 32, 'dropout': 0.1, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 905, 'train_loss': 0.5520377469, 'train_acc': 0.7348726115, 'val_acc': 0.5605031949, 'noiseless_val_acc': 0.5616014377, 'final_train_acc': 0.7531847134, 'final_val_acc': 0.5541134185, 'final_noiseless_val_acc': 0.5558107029, 'lr': 0.000151, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.1, 'depth': 2, 'cell_type': 'LSTM'}, {'epoch': 3, 'train_loss': 0.826132083, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.051794, 'emb_size': 32, 'hidden_size': 128, 'dropout': 0.1, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.7246990735, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.27778, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.05, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.6955985457, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.014842, 'emb_size': 64, 'hidden_size': 32, 'dropout': 0.1, 'depth': 1, 'cell_type': 'LSTM'}, {'epoch': 908, 'train_loss': 0.1314664802, 'train_acc': 0.9836783439, 'val_acc': 0.5418330671, 'noiseless_val_acc': 0.5451277955, 'final_train_acc': 0.9882563694, 'final_val_acc': 0.532048722, 'final_noiseless_val_acc': 0.5418330671, 'lr': 0.004229, 'emb_size': 64, 'hidden_size': 32, 'dropout': 0.05, 'depth': 2, 'cell_type': 'LSTM'}, {'epoch': 937, 'train_loss': 0.04158824017, 'train_acc': 0.9988057325, 'val_acc': 0.6212060703, 'noiseless_val_acc': 0.6308905751, 'final_train_acc': 0.9990047771, 'final_val_acc': 0.615215655, 'final_noiseless_val_acc': 0.6252995208, 'lr': 0.000346, 'emb_size': 32, 'hidden_size': 32, 'dropout': 0.05, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 842, 'train_loss': 0.003224395531, 'train_acc': 0.9990047771, 'val_acc': 0.5522164537, 'noiseless_val_acc': 0.553115016, 'final_train_acc': 0.9994028662, 'final_val_acc': 0.540634984, 'final_noiseless_val_acc': 0.5440295527, 'lr': 0.0001, 'emb_size': 128, 'hidden_size': 128, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 1.036432815, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.4777070064, 'final_val_acc': 0.4986022364, 'final_noiseless_val_acc': 0.4986022364, 'lr': 0.18197, 'emb_size': 16, 'hidden_size': 64, 'dropout': 0.05, 'depth': 6, 'cell_type': 'LSTM'}, {'epoch': 603, 'train_loss': 0.6528550963, 'train_acc': 0.596138535, 'val_acc': 0.5118809904, 'noiseless_val_acc': 0.5086861022, 'final_train_acc': 0.644705414, 'final_val_acc': 0.4959065495, 'final_noiseless_val_acc': 0.4944089457, 'lr': 0.004229, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.1, 'depth': 1, 'cell_type': 'LSTM'}, {'epoch': 916, 'train_loss': 0.003419683155, 'train_acc': 0.9992038217, 'val_acc': 0.5500199681, 'noiseless_val_acc': 0.5532148562, 'final_train_acc': 0.9994028662, 'final_val_acc': 0.5419329073, 'final_noiseless_val_acc': 0.5454273163, 'lr': 0.000229, 'emb_size': 32, 'hidden_size': 128, 'dropout': 0.05, 'de ...
# Loading: RNN_sparse_parity_k4_nbits21_n5000_bf2_seed1234
# [{'epoch': 1, 'train_loss': 0.7545940128, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.022516, 'emb_size': 64, 'hidden_size': 128, 'dropout': 0.1, 'depth': 6, 'cell_type': 'LSTM'}, {'epoch': 536, 'train_loss': 0.2409163514, 'train_acc': 0.9104299363, 'val_acc': 0.5205670927, 'noiseless_val_acc': 0.5192691693, 'final_train_acc': 0.9695461783, 'final_val_acc': 0.5164736422, 'final_noiseless_val_acc': 0.5129792332, 'lr': 0.000346, 'emb_size': 32, 'hidden_size': 32, 'dropout': 0.1, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 88, 'train_loss': 0.6919639737, 'train_acc': 0.5232882166, 'val_acc': 0.5027955272, 'noiseless_val_acc': 0.5027955272, 'final_train_acc': 0.5863853503, 'final_val_acc': 0.4921126198, 'final_noiseless_val_acc': 0.4972044728, 'lr': 0.000151, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.1, 'depth': 2, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.9654354039, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.051794, 'emb_size': 32, 'hidden_size': 128, 'dropout': 0.1, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.7268091869, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.27778, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.05, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.6956461752, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.014842, 'emb_size': 64, 'hidden_size': 32, 'dropout': 0.1, 'depth': 1, 'cell_type': 'LSTM'}, {'epoch': 440, 'train_loss': 0.2253849536, 'train_acc': 0.9323248408, 'val_acc': 0.5199680511, 'noiseless_val_acc': 0.5154752396, 'final_train_acc': 0.960589172, 'final_val_acc': 0.5067891374, 'final_noiseless_val_acc': 0.5122803514, 'lr': 0.004229, 'emb_size': 64, 'hidden_size': 32, 'dropout': 0.05, 'depth': 2, 'cell_type': 'LSTM'}, {'epoch': 300, 'train_loss': 0.3433851305, 'train_acc': 0.8409633758, 'val_acc': 0.5189696486, 'noiseless_val_acc': 0.5177715655, 'final_train_acc': 0.9880573248, 'final_val_acc': 0.5121805112, 'final_noiseless_val_acc': 0.5156749201, 'lr': 0.000346, 'emb_size': 32, 'hidden_size': 32, 'dropout': 0.05, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 935, 'train_loss': 0.002204783038, 'train_acc': 0.9996019108, 'val_acc': 0.5433306709, 'noiseless_val_acc': 0.5443290735, 'final_train_acc': 0.9996019108, 'final_val_acc': 0.5378394569, 'final_noiseless_val_acc': 0.5348442492, 'lr': 0.0001, 'emb_size': 128, 'hidden_size': 128, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 2, 'train_loss': 0.8829997451, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.18197, 'emb_size': 16, 'hidden_size': 64, 'dropout': 0.05, 'depth': 6, 'cell_type': 'LSTM'}, {'epoch': 407, 'train_loss': 0.6909842442, 'train_acc': 0.5272691083, 'val_acc': 0.5053913738, 'noiseless_val_acc': 0.5043929712, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.004229, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.1, 'depth': 1, 'cell_type': 'LSTM'}, {'epoch': 305, 'train_loss': 0.02380393385, 'train_acc': 0.9974124204, 'val_acc': 0.5542132588, 'noiseless_val_acc': 0.5540135783, 'final_train_acc': 0.9992038217, 'final_val_acc': 0.5533146965, 'final_noiseless_val_acc': 0.5593051118, 'lr': 0.000229, 'emb_size': 32, 'hidden_size': 128, 'dropout': 0.05,  ...
# Loading: RNN_sparse_parity_k4_nbits21_n5000_bf5_seed1234
# [{'epoch': 1, 'train_loss': 0.7684191792, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.022516, 'emb_size': 64, 'hidden_size': 128, 'dropout': 0.1, 'depth': 6, 'cell_type': 'LSTM'}, {'epoch': 798, 'train_loss': 0.1266834862, 'train_acc': 0.9932324841, 'val_acc': 0.530451278, 'noiseless_val_acc': 0.5240615016, 'final_train_acc': 0.996616242, 'final_val_acc': 0.5251597444, 'final_noiseless_val_acc': 0.5255591054, 'lr': 0.000346, 'emb_size': 32, 'hidden_size': 32, 'dropout': 0.1, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 923, 'train_loss': 0.5881028758, 'train_acc': 0.7004378981, 'val_acc': 0.518370607, 'noiseless_val_acc': 0.5216653355, 'final_train_acc': 0.7141719745, 'final_val_acc': 0.5147763578, 'final_noiseless_val_acc': 0.5232627796, 'lr': 0.000151, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.1, 'depth': 2, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.8890618021, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.051794, 'emb_size': 32, 'hidden_size': 128, 'dropout': 0.1, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.7268611827, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.27778, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.05, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.695763818, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.014842, 'emb_size': 64, 'hidden_size': 32, 'dropout': 0.1, 'depth': 1, 'cell_type': 'LSTM'}, {'epoch': 255, 'train_loss': 0.3412406962, 'train_acc': 0.8968949045, 'val_acc': 0.5048921725, 'noiseless_val_acc': 0.4976038339, 'final_train_acc': 0.9211783439, 'final_val_acc': 0.5026956869, 'final_noiseless_val_acc': 0.5051916933, 'lr': 0.004229, 'emb_size': 64, 'hidden_size': 32, 'dropout': 0.05, 'depth': 2, 'cell_type': 'LSTM'}, {'epoch': 191, 'train_loss': 0.5303671904, 'train_acc': 0.7328821656, 'val_acc': 0.5162739617, 'noiseless_val_acc': 0.5167731629, 'final_train_acc': 0.9470541401, 'final_val_acc': 0.5101837061, 'final_noiseless_val_acc': 0.5157747604, 'lr': 0.000346, 'emb_size': 32, 'hidden_size': 32, 'dropout': 0.05, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 256, 'train_loss': 0.07661117815, 'train_acc': 0.9215764331, 'val_acc': 0.5318490415, 'noiseless_val_acc': 0.5305511182, 'final_train_acc': 0.9984076433, 'final_val_acc': 0.526158147, 'final_noiseless_val_acc': 0.5212659744, 'lr': 0.0001, 'emb_size': 128, 'hidden_size': 128, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 4, 'train_loss': 1.022266928, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.18197, 'emb_size': 16, 'hidden_size': 64, 'dropout': 0.05, 'depth': 6, 'cell_type': 'LSTM'}, {'epoch': 323, 'train_loss': 0.6421713241, 'train_acc': 0.6128582803, 'val_acc': 0.5087859425, 'noiseless_val_acc': 0.5017971246, 'final_train_acc': 0.6652070064, 'final_val_acc': 0.4973043131, 'final_noiseless_val_acc': 0.4990015974, 'lr': 0.004229, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.1, 'depth': 1, 'cell_type': 'LSTM'}, {'epoch': 884, 'train_loss': 0.003703295125, 'train_acc': 0.9994028662, 'val_acc': 0.5267571885, 'noiseless_val_acc': 0.5246605431, 'final_train_acc': 0.9990047771, 'final_val_acc': 0.5217651757, 'final_noiseless_val_acc': 0.523063099, 'lr': 0.000229, 'emb_size': 32, 'hidden_size': 128, 'dropout': 0.05, 'dept ...
# Loading: RNN_sparse_parity_k4_nbits21_n5000_bf7.5_seed1234
# [{'epoch': 1, 'train_loss': 0.9255994361, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.4777070064, 'final_val_acc': 0.4986022364, 'final_noiseless_val_acc': 0.4986022364, 'lr': 0.051794, 'emb_size': 64, 'hidden_size': 128, 'dropout': 0.1, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.7100770937, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.078804, 'emb_size': 128, 'hidden_size': 32, 'dropout': 0.1, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 110, 'train_loss': 0.1880032518, 'train_acc': 0.866839172, 'val_acc': 0.5147763578, 'noiseless_val_acc': 0.5030950479, 'final_train_acc': 0.9972133758, 'final_val_acc': 0.5044928115, 'final_noiseless_val_acc': 0.5088857827, 'lr': 0.000796, 'emb_size': 32, 'hidden_size': 128, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.6953232543, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.009774, 'emb_size': 128, 'hidden_size': 32, 'dropout': 0.1, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 83, 'train_loss': 0.5758711698, 'train_acc': 0.710589172, 'val_acc': 0.5165734824, 'noiseless_val_acc': 0.509784345, 'final_train_acc': 0.9954219745, 'final_val_acc': 0.5090854633, 'final_noiseless_val_acc': 0.5106829073, 'lr': 0.002782, 'emb_size': 16, 'hidden_size': 128, 'dropout': 0.1, 'depth': 2, 'cell_type': 'LSTM'}, {'epoch': 154, 'train_loss': 0.685712481, 'train_acc': 0.5535429936, 'val_acc': 0.5109824281, 'noiseless_val_acc': 0.5033945687, 'final_train_acc': 0.6892914013, 'final_val_acc': 0.5053913738, 'final_noiseless_val_acc': 0.5119808307, 'lr': 0.000229, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.6971159467, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.022516, 'emb_size': 16, 'hidden_size': 32, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.9225237614, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.078804, 'emb_size': 32, 'hidden_size': 128, 'dropout': 0.1, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 353, 'train_loss': 0.5860151267, 'train_acc': 0.724522293, 'val_acc': 0.508985623, 'noiseless_val_acc': 0.4959065495, 'final_train_acc': 0.8079219745, 'final_val_acc': 0.5022963259, 'final_noiseless_val_acc': 0.4971046326, 'lr': 0.000525, 'emb_size': 16, 'hidden_size': 16, 'dropout': 0.1, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 965, 'train_loss': 0.01092288411, 'train_acc': 0.9990047771, 'val_acc': 0.5419329073, 'noiseless_val_acc': 0.563298722, 'final_train_acc': 0.9992038217, 'final_val_acc': 0.532048722, 'final_noiseless_val_acc': 0.5598043131, 'lr': 0.001206, 'emb_size': 64, 'hidden_size': 128, 'dropout': 0.05, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 226, 'train_loss': 0.6915878023, 'train_acc': 0.5292595541, 'val_acc': 0.508985623, 'noiseless_val_acc': 0.5004992013, 'final_train_acc': 0.534633758, 'final_val_acc': 0.4984025559, 'final_noiseless_val_acc': 0.4973043131, 'lr': 0.006428, 'emb_size': 64, 'hidden_size': 16, 'dropout': 0.1, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.6947522129, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.009774, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.1, 'depth': 5 ...
# Loading: RNN_sparse_parity_k4_nbits21_n5000_bf10_seed1234
# [{'epoch': 162, 'train_loss': 0.04728477266, 'train_acc': 0.9936305732, 'val_acc': 0.5170726837, 'noiseless_val_acc': 0.5147763578, 'lr': 0.000525, 'emb_size': 128, 'hidden_size': 128, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 90, 'train_loss': 0.6704700035, 'train_acc': 0.5828025478, 'val_acc': 0.5119808307, 'noiseless_val_acc': 0.5153753994, 'lr': 0.000229, 'emb_size': 64, 'hidden_size': 64, 'dropout': 0.05, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 70, 'train_loss': 0.6851952178, 'train_acc': 0.5561305732, 'val_acc': 0.5160742812, 'noiseless_val_acc': 0.5142771565, 'lr': 0.000346, 'emb_size': 32, 'hidden_size': 32, 'dropout': 0.1, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 69, 'train_loss': 0.6885107289, 'train_acc': 0.5535429936, 'val_acc': 0.5147763578, 'noiseless_val_acc': 0.5051916933, 'lr': 0.000525, 'emb_size': 16, 'hidden_size': 32, 'dropout': 0.1, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 88, 'train_loss': 0.6847455536, 'train_acc': 0.5531449045, 'val_acc': 0.5121805112, 'noiseless_val_acc': 0.5135782748, 'lr': 0.000151, 'emb_size': 64, 'hidden_size': 64, 'dropout': 0.05, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 88, 'train_loss': 0.6864406368, 'train_acc': 0.5477707006, 'val_acc': 0.518370607, 'noiseless_val_acc': 0.5043929712, 'lr': 0.000151, 'emb_size': 128, 'hidden_size': 64, 'dropout': 0.1, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 48, 'train_loss': 0.6894596109, 'train_acc': 0.5463773885, 'val_acc': 0.5100838658, 'noiseless_val_acc': 0.4954073482, 'lr': 0.000229, 'emb_size': 128, 'hidden_size': 64, 'dropout': 0.1, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 119, 'train_loss': 0.6870468156, 'train_acc': 0.5449840764, 'val_acc': 0.5159744409, 'noiseless_val_acc': 0.5071884984, 'lr': 0.0001, 'emb_size': 128, 'hidden_size': 64, 'dropout': 0.1, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 65, 'train_loss': 0.6894477883, 'train_acc': 0.5402070064, 'val_acc': 0.5130790735, 'noiseless_val_acc': 0.5063897764, 'lr': 0.000346, 'emb_size': 16, 'hidden_size': 32, 'dropout': 0.05, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 61, 'train_loss': 0.6906070292, 'train_acc': 0.5362261146, 'val_acc': 0.5149760383, 'noiseless_val_acc': 0.508186901, 'lr': 0.000151, 'emb_size': 128, 'hidden_size': 128, 'dropout': 0.1, 'depth': 6, 'cell_type': 'LSTM'}, {'epoch': 67, 'train_loss': 0.6917866374, 'train_acc': 0.5356289809, 'val_acc': 0.5120806709, 'noiseless_val_acc': 0.5002995208, 'lr': 0.000151, 'emb_size': 64, 'hidden_size': 32, 'dropout': 0.1, 'depth': 6, 'cell_type': 'LSTM'}, {'epoch': 92, 'train_loss': 0.6892962953, 'train_acc': 0.5340366242, 'val_acc': 0.5127795527, 'noiseless_val_acc': 0.5073881789, 'lr': 0.000151, 'emb_size': 32, 'hidden_size': 128, 'dropout': 0.1, 'depth': 6, 'cell_type': 'LSTM'}, {'epoch': 51, 'train_loss': 0.6919168743, 'train_acc': 0.5334394904, 'val_acc': 0.5157747604, 'noiseless_val_acc': 0.4967052716, 'lr': 0.000796, 'emb_size': 64, 'hidden_size': 16, 'dropout': 0.05, 'depth': 6, 'cell_type': 'LSTM'}, {'epoch': 58, 'train_loss': 0.6908886649, 'train_acc': 0.5320461783, 'val_acc': 0.5121805112, 'noiseless_val_acc': 0.5051916933, 'lr': 0.000229, 'emb_size': 16, 'hidden_size': 64, 'dropout': 0.05, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 40, 'train_loss': 0.6912173667, 'train_acc': 0.5318471338, 'val_acc': 0.5117811502, 'noiseless_val_acc': 0.5010982428, 'lr': 0.000525, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.05, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 35, 'train_loss': 0.6914086198, 'train_acc': 0.5314490446, 'val_acc': 0.509784345, 'noiseless_val_acc': 0.5052915335, 'lr': 0.000525, 'emb_size': 16, 'hidden_size': 64, 'dropout': 0.1, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 39, 'train_loss': 0.6893402581, 'train_acc': 0.5306528662, 'val_acc': 0.5096845048, 'noiseless_val_acc': 0.5075878594, 'lr': 0.001206, 'emb_size': 64, 'hidden_size': 64, 'dropout': 0.1, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 124, 'train_loss': 0.6912605231, 'train_acc': 0.5304538217, 'val_ ...
# Loading: RNN_sparse_parity_k4_nbits21_n5000_bf12.5_seed1234
# [{'epoch': 1, 'train_loss': 0.8650537798, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.051794, 'emb_size': 64, 'hidden_size': 128, 'dropout': 0.1, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.7101896671, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.078804, 'emb_size': 128, 'hidden_size': 32, 'dropout': 0.1, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 652, 'train_loss': 0.01604999934, 'train_acc': 0.9988057325, 'val_acc': 0.5160742812, 'noiseless_val_acc': 0.508186901, 'final_train_acc': 0.9988057325, 'final_val_acc': 0.5041932907, 'final_noiseless_val_acc': 0.5020966454, 'lr': 0.000796, 'emb_size': 32, 'hidden_size': 128, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.6953135729, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.009774, 'emb_size': 128, 'hidden_size': 32, 'dropout': 0.1, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 70, 'train_loss': 0.44058615, 'train_acc': 0.8107085987, 'val_acc': 0.5111821086, 'noiseless_val_acc': 0.5051916933, 'final_train_acc': 0.9972133758, 'final_val_acc': 0.4995007987, 'final_noiseless_val_acc': 0.5016972843, 'lr': 0.002782, 'emb_size': 16, 'hidden_size': 128, 'dropout': 0.1, 'depth': 2, 'cell_type': 'LSTM'}, {'epoch': 179, 'train_loss': 0.6749481247, 'train_acc': 0.5736464968, 'val_acc': 0.5091853035, 'noiseless_val_acc': 0.5036940895, 'final_train_acc': 0.6624203822, 'final_val_acc': 0.5022963259, 'final_noiseless_val_acc': 0.4999001597, 'lr': 0.000229, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.6950204505, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.022516, 'emb_size': 16, 'hidden_size': 32, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 2, 'train_loss': 0.945746188, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.078804, 'emb_size': 32, 'hidden_size': 128, 'dropout': 0.1, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 61, 'train_loss': 0.6886894092, 'train_acc': 0.5463773885, 'val_acc': 0.5094848243, 'noiseless_val_acc': 0.4952076677, 'final_train_acc': 0.7197452229, 'final_val_acc': 0.4983027157, 'final_noiseless_val_acc': 0.5068889776, 'lr': 0.000525, 'emb_size': 16, 'hidden_size': 16, 'dropout': 0.1, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 159, 'train_loss': 0.1024360587, 'train_acc': 0.976910828, 'val_acc': 0.5135782748, 'noiseless_val_acc': 0.5082867412, 'final_train_acc': 0.9988057325, 'final_val_acc': 0.5063897764, 'final_noiseless_val_acc': 0.5115814696, 'lr': 0.001206, 'emb_size': 64, 'hidden_size': 128, 'dropout': 0.05, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 588, 'train_loss': 0.6839219453, 'train_acc': 0.5623009554, 'val_acc': 0.5129792332, 'noiseless_val_acc': 0.5036940895, 'final_train_acc': 0.6427149682, 'final_val_acc': 0.4998003195, 'final_noiseless_val_acc': 0.5068889776, 'lr': 0.006428, 'emb_size': 64, 'hidden_size': 16, 'dropout': 0.1, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.6947494237, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.009774, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.1, 'depth ...
# Loading: RNN_sparse_parity_k4_nbits21_n5000_bf15_seed1234
# [{'epoch': 1, 'train_loss': 0.882998408, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.4777070064, 'final_val_acc': 0.4986022364, 'final_noiseless_val_acc': 0.4986022364, 'lr': 0.051794, 'emb_size': 64, 'hidden_size': 128, 'dropout': 0.1, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.7101648974, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.078804, 'emb_size': 128, 'hidden_size': 32, 'dropout': 0.1, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 116, 'train_loss': 0.0913819463, 'train_acc': 0.9498407643, 'val_acc': 0.5123801917, 'noiseless_val_acc': 0.4959065495, 'final_train_acc': 0.9984076433, 'final_val_acc': 0.5033945687, 'final_noiseless_val_acc': 0.4973043131, 'lr': 0.000796, 'emb_size': 32, 'hidden_size': 128, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.6953108527, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.009774, 'emb_size': 128, 'hidden_size': 32, 'dropout': 0.1, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 367, 'train_loss': 0.05152273339, 'train_acc': 0.9950238854, 'val_acc': 0.5161741214, 'noiseless_val_acc': 0.5135782748, 'final_train_acc': 0.9978105096, 'final_val_acc': 0.5055910543, 'final_noiseless_val_acc': 0.5156749201, 'lr': 0.002782, 'emb_size': 16, 'hidden_size': 128, 'dropout': 0.1, 'depth': 2, 'cell_type': 'LSTM'}, {'epoch': 430, 'train_loss': 0.5988393787, 'train_acc': 0.6875, 'val_acc': 0.5083865815, 'noiseless_val_acc': 0.5025958466, 'final_train_acc': 0.7710987261, 'final_val_acc': 0.5010982428, 'final_noiseless_val_acc': 0.4967052716, 'lr': 0.000229, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.694987638, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.022516, 'emb_size': 16, 'hidden_size': 32, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 2, 'train_loss': 0.8651522622, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.078804, 'emb_size': 32, 'hidden_size': 128, 'dropout': 0.1, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 55, 'train_loss': 0.6906076165, 'train_acc': 0.5406050955, 'val_acc': 0.5103833866, 'noiseless_val_acc': 0.4995007987, 'final_train_acc': 0.6737659236, 'final_val_acc': 0.4940095847, 'final_noiseless_val_acc': 0.499600639, 'lr': 0.000525, 'emb_size': 16, 'hidden_size': 16, 'dropout': 0.1, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 170, 'train_loss': 0.03939091253, 'train_acc': 0.9962181529, 'val_acc': 0.5143769968, 'noiseless_val_acc': 0.5066892971, 'final_train_acc': 0.9990047771, 'final_val_acc': 0.5063897764, 'final_noiseless_val_acc': 0.5032947284, 'lr': 0.001206, 'emb_size': 64, 'hidden_size': 128, 'dropout': 0.05, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 328, 'train_loss': 0.6832446676, 'train_acc': 0.5652866242, 'val_acc': 0.5146765176, 'noiseless_val_acc': 0.5054912141, 'final_train_acc': 0.6403264331, 'final_val_acc': 0.5031948882, 'final_noiseless_val_acc': 0.5014976038, 'lr': 0.006428, 'emb_size': 64, 'hidden_size': 16, 'dropout': 0.1, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.6947446276, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.009774, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.1, 'depth': ...
# Loading: RNN_sparse_parity_k4_nbits21_n5000_bf17.5_seed1234
# [{'epoch': 1, 'train_loss': 0.8687106682, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.051794, 'emb_size': 64, 'hidden_size': 128, 'dropout': 0.1, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.7098843026, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.078804, 'emb_size': 128, 'hidden_size': 32, 'dropout': 0.1, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 23, 'train_loss': 0.6915688727, 'train_acc': 0.5296576433, 'val_acc': 0.5067891374, 'noiseless_val_acc': 0.4993011182, 'final_train_acc': 0.9990047771, 'final_val_acc': 0.4976038339, 'final_noiseless_val_acc': 0.5091853035, 'lr': 0.000796, 'emb_size': 32, 'hidden_size': 128, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.6953106853, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.009774, 'emb_size': 128, 'hidden_size': 32, 'dropout': 0.1, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 200, 'train_loss': 0.1340814049, 'train_acc': 0.986066879, 'val_acc': 0.5114816294, 'noiseless_val_acc': 0.5110822684, 'final_train_acc': 0.9952229299, 'final_val_acc': 0.4982028754, 'final_noiseless_val_acc': 0.5162739617, 'lr': 0.002782, 'emb_size': 16, 'hidden_size': 128, 'dropout': 0.1, 'depth': 2, 'cell_type': 'LSTM'}, {'epoch': 302, 'train_loss': 0.6550270987, 'train_acc': 0.6150477707, 'val_acc': 0.5126797125, 'noiseless_val_acc': 0.4993011182, 'final_train_acc': 0.7414410828, 'final_val_acc': 0.4991014377, 'final_noiseless_val_acc': 0.4985023962, 'lr': 0.000229, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.6953074522, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.022516, 'emb_size': 16, 'hidden_size': 32, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.9147132487, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.078804, 'emb_size': 32, 'hidden_size': 128, 'dropout': 0.1, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 269, 'train_loss': 0.645612214, 'train_acc': 0.6327627389, 'val_acc': 0.5112819489, 'noiseless_val_acc': 0.5069888179, 'final_train_acc': 0.7300955414, 'final_val_acc': 0.4958067093, 'final_noiseless_val_acc': 0.5023961661, 'lr': 0.000525, 'emb_size': 16, 'hidden_size': 16, 'dropout': 0.1, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 71, 'train_loss': 0.6801868977, 'train_acc': 0.5853901274, 'val_acc': 0.5134784345, 'noiseless_val_acc': 0.5001996805, 'final_train_acc': 0.997611465, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5033945687, 'lr': 0.001206, 'emb_size': 64, 'hidden_size': 128, 'dropout': 0.05, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 493, 'train_loss': 0.6901974393, 'train_acc': 0.5429936306, 'val_acc': 0.5103833866, 'noiseless_val_acc': 0.5006988818, 'final_train_acc': 0.5925557325, 'final_val_acc': 0.5066892971, 'final_noiseless_val_acc': 0.5005990415, 'lr': 0.006428, 'emb_size': 64, 'hidden_size': 16, 'dropout': 0.1, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.6947472707, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.009774, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.1, 'dept ...
# Loading: RNN_sparse_parity_k4_nbits21_n5000_bf20_seed1234
# [{'epoch': 1, 'train_loss': 0.7432787775, 'train_acc': 0.494227707, 'val_acc': 0.5086861022, 'noiseless_val_acc': 0.5086861022, 'lr': 0.022516, 'emb_size': 64, 'hidden_size': 128, 'dropout': 0.1, 'depth': 6, 'cell_type': 'LSTM'}, {'epoch': 12, 'train_loss': 0.6936482195, 'train_acc': 0.5065684713, 'val_acc': 0.5108825879, 'noiseless_val_acc': 0.5120806709, 'lr': 0.000346, 'emb_size': 32, 'hidden_size': 32, 'dropout': 0.1, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 2, 'train_loss': 0.6931342035, 'train_acc': 0.4988057325, 'val_acc': 0.4990015974, 'noiseless_val_acc': 0.5022963259, 'lr': 0.000151, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.1, 'depth': 2, 'cell_type': 'LSTM'}, {'epoch': 2, 'train_loss': 0.789234527, 'train_acc': 0.494227707, 'val_acc': 0.5086861022, 'noiseless_val_acc': 0.5086861022, 'lr': 0.051794, 'emb_size': 32, 'hidden_size': 128, 'dropout': 0.1, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.7726313851, 'train_acc': 0.505772293, 'val_acc': 0.4913138978, 'noiseless_val_acc': 0.4913138978, 'lr': 0.27778, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.05, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.697399251, 'train_acc': 0.505772293, 'val_acc': 0.4913138978, 'noiseless_val_acc': 0.4913138978, 'lr': 0.014842, 'emb_size': 64, 'hidden_size': 32, 'dropout': 0.1, 'depth': 1, 'cell_type': 'LSTM'}, {'epoch': 6, 'train_loss': 0.6935186534, 'train_acc': 0.494227707, 'val_acc': 0.5086861022, 'noiseless_val_acc': 0.5086861022, 'lr': 0.004229, 'emb_size': 64, 'hidden_size': 32, 'dropout': 0.05, 'depth': 2, 'cell_type': 'LSTM'}, {'epoch': 14, 'train_loss': 0.693565175, 'train_acc': 0.5121417197, 'val_acc': 0.5090854633, 'noiseless_val_acc': 0.5095846645, 'lr': 0.000346, 'emb_size': 32, 'hidden_size': 32, 'dropout': 0.05, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 2, 'train_loss': 0.6936076264, 'train_acc': 0.4990047771, 'val_acc': 0.5096845048, 'noiseless_val_acc': 0.5116813099, 'lr': 0.0001, 'emb_size': 128, 'hidden_size': 128, 'dropout': 0.05, 'depth': 3, 'cell_type': 'LSTM'}, {'epoch': 3, 'train_loss': 0.9759909833, 'train_acc': 0.494227707, 'val_acc': 0.5086861022, 'noiseless_val_acc': 0.5086861022, 'lr': 0.18197, 'emb_size': 16, 'hidden_size': 64, 'dropout': 0.05, 'depth': 6, 'cell_type': 'LSTM'}, {'epoch': 3, 'train_loss': 0.6935601299, 'train_acc': 0.494227707, 'val_acc': 0.5086861022, 'noiseless_val_acc': 0.5086861022, 'lr': 0.004229, 'emb_size': 128, 'hidden_size': 16, 'dropout': 0.1, 'depth': 1, 'cell_type': 'LSTM'}, {'epoch': 57, 'train_loss': 0.6729740751, 'train_acc': 0.5786226115, 'val_acc': 0.5139776358, 'noiseless_val_acc': 0.5048921725, 'lr': 0.000229, 'emb_size': 32, 'hidden_size': 128, 'dropout': 0.05, 'depth': 5, 'cell_type': 'LSTM'}, {'epoch': 24, 'train_loss': 0.6930003481, 'train_acc': 0.5127388535, 'val_acc': 0.5127795527, 'noiseless_val_acc': 0.5018969649, 'lr': 0.000151, 'emb_size': 128, 'hidden_size': 64, 'dropout': 0.1, 'depth': 4, 'cell_type': 'LSTM'}, {'epoch': 32, 'train_loss': 0.6933612076, 'train_acc': 0.494227707, 'val_acc': 0.5086861022, 'noiseless_val_acc': 0.5086861022, 'lr': 0.004229, 'emb_size': 64, 'hidden_size': 128, 'dropout': 0.1, 'depth': 6, 'cell_type': 'LSTM'}, {'epoch': 6, 'train_loss': 0.6935100293, 'train_acc': 0.5051751592, 'val_acc': 0.5077875399, 'noiseless_val_acc': 0.5051916933, 'lr': 0.000229, 'emb_size': 32, 'hidden_size': 32, 'dropout': 0.05, 'depth': 1, 'cell_type': 'LSTM'}, {'epoch': 2, 'train_loss': 0.6938970036, 'train_acc': 0.508160828, 'val_acc': 0.4975039936, 'noiseless_val_acc': 0.5027955272, 'lr': 0.004229, 'emb_size': 32, 'hidden_size': 128, 'dropout': 0.05, 'depth': 1, 'cell_type': 'LSTM'}, {'epoch': 1, 'train_loss': 0.7253358979, 'train_acc': 0.505772293, 'val_acc': 0.4913138978, 'noiseless_val_acc': 0.4913138978, 'lr': 0.022516, 'emb_size': 128, 'hidden_size': 128, 'dropout': 0.05, 'depth': 1, 'cell_type': 'LSTM'}, {'epoch': 10, 'train_loss': 0.6935317866, 'train_acc': 0.494227707, 'val_acc': 0.5086861022, 'no ...
# Loading: SAN_sparse_parity_k4_nbits21_n5000_bf0_seed1234
# [{'lr': 0.001, 'depth': 4, 'd_model': 32, 'dropout': 0.05, 'heads': 4, 'd_ffn': 128, 'epoch': 126, 'train_loss': 0.07376875369, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.001585, 'depth': 5, 'd_model': 16, 'dropout': 0.05, 'heads': 2, 'd_ffn': 64, 'epoch': 119, 'train_loss': 0.154807039, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.000631, 'depth': 5, 'd_model': 64, 'dropout': 0.05, 'heads': 4, 'd_ffn': 64, 'epoch': 79, 'train_loss': 0.2551086716, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.001585, 'depth': 1, 'd_model': 64, 'dropout': 0.05, 'heads': 8, 'd_ffn': 64, 'epoch': 42, 'train_loss': 0.1153232738, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.000631, 'depth': 3, 'd_model': 64, 'dropout': 0.1, 'heads': 8, 'd_ffn': 64, 'epoch': 74, 'train_loss': 0.1353683796, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.002512, 'depth': 3, 'd_model': 16, 'dropout': 0.05, 'heads': 8, 'd_ffn': 32, 'epoch': 99, 'train_loss': 0.01386776788, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.000398, 'depth': 6, 'd_model': 32, 'dropout': 0.05, 'heads': 4, 'd_ffn': 64, 'epoch': 108, 'train_loss': 0.06023278537, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.001, 'depth': 1, 'd_model': 16, 'dropout': 0.1, 'heads': 8, 'd_ffn': 64, 'epoch': 171, 'train_loss': 0.2576845377, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.001, 'depth': 6, 'd_model': 32, 'dropout': 0.05, 'heads': 8, 'd_ffn': 32, 'epoch': 129, 'train_loss': 0.02242389584, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.000398, 'depth': 3, 'd_model': 32, 'dropout': 0.05, 'heads': 4, 'd_ffn': 128, 'epoch': 161, 'train_loss': 0.04332159487, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.003981, 'depth': 2, 'd_model': 32, 'dropout': 0.05, 'heads': 4, 'd_ffn': 32, 'epoch': 211, 'train_loss': 0.1675038943, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.001, 'depth': 3, 'd_model': 64, 'dropout': 0.05, 'heads': 8, 'd_ffn': 32, 'epoch': 48, 'train_loss': 0.01128705103, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.003981, 'depth': 5, 'd_model': 32, 'dropout': 0.05, 'heads': 4, 'd_ffn': 32, 'epoch': 44, 'train_loss': 0.1311450084, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.002512, 'depth': 6, 'd_model': 32, 'dropout': 0.05, 'heads': 2, 'd_ffn': 32, 'epoch': 115, 'train_loss': 0.2095752144, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.000398, 'depth': 4, 'd_model': 32, 'dropout': 0.1, 'heads': 8, 'd_ffn': 32, 'epoch': 124, 'train_loss': 0.1683169785, 'train_acc': 0.9998009554, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.000398, 'depth': 5, 'd_model': 32, 'dropout': 0.05, 'heads': 2, 'd_ffn': 64, 'epoch': 233, 'train_loss': 0.04100879812, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.003981, 'depth': 5, 'd_model': 16, 'dropout': 0.05, 'heads': 8, 'd_ffn': 32, 'epoch': 82, 'train_loss': 0.1121852035, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.000398, 'depth': 5, 'd_model': 16, 'dropout': 0.05, 'heads': 8, 'd_ffn': 128, 'epoch': 110, 'train_loss': 0.1352883737, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.000631, 'depth': 2, 'd_model': 64, 'dropout': 0.1, 'heads': 8, 'd_ffn': 64, 'epoch': 74, 'train_loss': 0.04110849614, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.002512, 'depth': 2, 'd_model': 32, 'dropout': 0.1, 'heads': 4, 'd_ffn': 64, 'epoch': 67, 'train_loss': 0.07669971322, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.000631, 'depth': 4, 'd_model': 32, 'dropout': 0.05, 'heads': 2, 'd_ffn': 32, 'epoch': 85, 'train_loss': 0.1007352541, 'train_acc': 1, 'val_acc': 1, 'noiseless_val_acc': 1}, {'lr': 0.001, 'depth': 2, 'd_model': 16, 'dropout': 0.05, 'heads': 2, 'd_ffn': 64, 'epoch': 77, 'train_loss': 0.08476000077, 'train_acc': 0.9998009554, 'val_acc' ...
# Loading: SAN_sparse_parity_k4_nbits21_n5000_bf1_seed1234
# ...
# Loading: SAN_sparse_parity_k4_nbits21_n5000_bf15_seed1234
# [{'epoch': 2, 'train_loss': 0.698780354, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.01, 'depth': 5, 'd_model': 32, 'dropout': 0.1, 'heads': 8, 'd_ffn': 64}, {'epoch': 4, 'train_loss': 0.7033818683, 'train_acc': 0.511544586, 'val_acc': 0.5026956869, 'noiseless_val_acc': 0.4968051118, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.001585, 'depth': 5, 'd_model': 128, 'dropout': 0.1, 'heads': 2, 'd_ffn': 64}, {'epoch': 4, 'train_loss': 0.7012066602, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.001585, 'depth': 5, 'd_model': 128, 'dropout': 0.05, 'heads': 2, 'd_ffn': 32}, {'epoch': 8, 'train_loss': 0.7183731145, 'train_acc': 0.5149283439, 'val_acc': 0.5063897764, 'noiseless_val_acc': 0.4995007987, 'final_train_acc': 0.5258757962, 'final_val_acc': 0.50389377, 'final_noiseless_val_acc': 0.5035942492, 'lr': 2.5e-05, 'depth': 5, 'd_model': 16, 'dropout': 0.05, 'heads': 4, 'd_ffn': 32}, {'epoch': 317, 'train_loss': 0.6718119595, 'train_acc': 0.5726512739, 'val_acc': 0.5176717252, 'noiseless_val_acc': 0.5060902556, 'final_train_acc': 0.7633359873, 'final_val_acc': 0.508586262, 'final_noiseless_val_acc': 0.5065894569, 'lr': 0.001585, 'depth': 4, 'd_model': 32, 'dropout': 0.05, 'heads': 4, 'd_ffn': 64}, {'epoch': 66, 'train_loss': 0.6915440639, 'train_acc': 0.5314490446, 'val_acc': 0.513678115, 'noiseless_val_acc': 0.5062899361, 'final_train_acc': 0.5782245223, 'final_val_acc': 0.5022963259, 'final_noiseless_val_acc': 0.5063897764, 'lr': 0.000251, 'depth': 4, 'd_model': 16, 'dropout': 0.05, 'heads': 2, 'd_ffn': 128}, {'epoch': 979, 'train_loss': 0.08661927964, 'train_acc': 0.9874601911, 'val_acc': 0.5217651757, 'noiseless_val_acc': 0.539836262, 'final_train_acc': 0.9880573248, 'final_val_acc': 0.5119808307, 'final_noiseless_val_acc': 0.5388378594, 'lr': 0.000631, 'depth': 4, 'd_model': 64, 'dropout': 0.05, 'heads': 8, 'd_ffn': 32}, {'epoch': 109, 'train_loss': 0.6897200707, 'train_acc': 0.5471735669, 'val_acc': 0.5137779553, 'noiseless_val_acc': 0.5078873802, 'final_train_acc': 0.5435907643, 'final_val_acc': 0.5040934505, 'final_noiseless_val_acc': 0.500399361, 'lr': 0.000631, 'depth': 3, 'd_model': 128, 'dropout': 0.05, 'heads': 4, 'd_ffn': 32}, {'epoch': 241, 'train_loss': 0.6911444561, 'train_acc': 0.5302547771, 'val_acc': 0.5153753994, 'noiseless_val_acc': 0.4993011182, 'final_train_acc': 0.5593152866, 'final_val_acc': 0.5056908946, 'final_noiseless_val_acc': 0.5052915335, 'lr': 6.3e-05, 'depth': 3, 'd_model': 128, 'dropout': 0.05, 'heads': 2, 'd_ffn': 32}, {'epoch': 261, 'train_loss': 0.6913179228, 'train_acc': 0.5326433121, 'val_acc': 0.5150758786, 'noiseless_val_acc': 0.5016972843, 'final_train_acc': 0.5374203822, 'final_val_acc': 0.5106829073, 'final_noiseless_val_acc': 0.5026956869, 'lr': 4e-05, 'depth': 5, 'd_model': 64, 'dropout': 0.1, 'heads': 4, 'd_ffn': 128}, {'epoch': 549, 'train_loss': 0.6878937749, 'train_acc': 0.5419984076, 'val_acc': 0.517172524, 'noiseless_val_acc': 0.5008985623, 'final_train_acc': 0.6962579618, 'final_val_acc': 0.5078873802, 'final_noiseless_val_acc': 0.5092851438, 'lr': 0.0001, 'depth': 5, 'd_model': 128, 'dropout': 0.1, 'heads': 8, 'd_ffn': 64}, {'epoch': 2, 'train_loss': 0.7015300796, 'train_acc': 0.511544586, 'val_acc': 0.5026956869, 'noiseless_val_acc': 0.4968051118, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.01, 'depth': 2, 'd_model': 32, 'dropout': 0.1, 'heads': 2, 'd_ffn': 32}, {'epoch': 42, 'train_loss': 0.6936269683, 'train_acc': 0.511544586, 'val_acc': 0.5026956869, 'noiseless_val_acc': 0.4968051118, 'final_train_acc': 0.5222929936, 'final_val_acc': 0. ...
# Loading: SAN_sparse_parity_k4_nbits21_n5000_bf17.5_seed1234
# [{'  epoch': '\\', 'train_loss': 0.6978391413, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.01, 'depth': 5, 'd_model': 32, 'dropout': 0.1, 'heads': 8, 'd_ffn': 64}, {'  epoch': 83, 'train_loss': 0.6966605452, 'train_acc': 0.5181130573, 'val_acc': 0.5086861022, 'noiseless_val_acc': 0.4991014377, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.001585, 'depth': 5, 'd_model': 128, 'dropout': 0.1, 'heads': 2, 'd_ffn': 64}, {'  epoch': 4, 'train_loss': 0.704272539, 'train_acc': 0.5222929936, 'val_acc': 0.5013977636, 'noiseless_val_acc': 0.5013977636, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.001585, 'depth': 5, 'd_model': 128, 'dropout': 0.05, 'heads': 2, 'd_ffn': 32}, {'  epoch': 7, 'train_loss': 0.7200322535, 'train_acc': 0.5167197452, 'val_acc': 0.5059904153, 'noiseless_val_acc': 0.5005990415, 'final_train_acc': 0.5298566879, 'final_val_acc': 0.5041932907, 'final_noiseless_val_acc': 0.5017971246, 'lr': 2.5e-05, 'depth': 5, 'd_model': 16, 'dropout': 0.05, 'heads': 4, 'd_ffn': 32}, {'  epoch': 262, 'train_loss': 0.6797037121, 'train_acc': 0.5710589172, 'val_acc': 0.517571885, 'noiseless_val_acc': 0.5031948882, 'final_train_acc': 0.7380573248, 'final_val_acc': 0.5052915335, 'final_noiseless_val_acc': 0.5091853035, 'lr': 0.001585, 'depth': 4, 'd_model': 32, 'dropout': 0.05, 'heads': 4, 'd_ffn': 64}, {'  epoch': 64, 'train_loss': 0.6912429261, 'train_acc': 0.5318471338, 'val_acc': 0.5153753994, 'noiseless_val_acc': 0.5076876997, 'final_train_acc': 0.5670780255, 'final_val_acc': 0.5027955272, 'final_noiseless_val_acc': 0.5008985623, 'lr': 0.000251, 'depth': 4, 'd_model': 16, 'dropout': 0.05, 'heads': 2, 'd_ffn': 128}, {'  epoch': 70, 'train_loss': 0.6907820876, 'train_acc': 0.5425955414, 'val_acc': 0.5172723642, 'noiseless_val_acc': 0.5043929712, 'final_train_acc': 0.9570063694, 'final_val_acc': 0.4912140575, 'final_noiseless_val_acc': 0.5105830671, 'lr': 0.000631, 'depth': 4, 'd_model': 64, 'dropout': 0.05, 'heads': 8, 'd_ffn': 32}, {'  epoch': 170, 'train_loss': 0.6893182454, 'train_acc': 0.5433917197, 'val_acc': 0.5158746006, 'noiseless_val_acc': 0.5055910543, 'final_train_acc': 0.5457802548, 'final_val_acc': 0.5044928115, 'final_noiseless_val_acc': 0.5000998403, 'lr': 0.000631, 'depth': 3, 'd_model': 128, 'dropout': 0.05, 'heads': 4, 'd_ffn': 32}, {'  epoch': 205, 'train_loss': 0.6917438906, 'train_acc': 0.5266719745, 'val_acc': 0.5156749201, 'noiseless_val_acc': 0.5027955272, 'final_train_acc': 0.5366242038, 'final_val_acc': 0.5015974441, 'final_noiseless_val_acc': 0.5019968051, 'lr': 6.3e-05, 'depth': 3, 'd_model': 128, 'dropout': 0.05, 'heads': 2, 'd_ffn': 32}, {'  epoch': 276, 'train_loss': 0.6910574326, 'train_acc': 0.5350318471, 'val_acc': 0.5145766773, 'noiseless_val_acc': 0.5068889776, 'final_train_acc': 0.5330414013, 'final_val_acc': 0.5026956869, 'final_noiseless_val_acc': 0.5026956869, 'lr': 4e-05, 'depth': 5, 'd_model': 64, 'dropout': 0.1, 'heads': 4, 'd_ffn': 128}, {'  epoch': 329, 'train_loss': 0.6884284061, 'train_acc': 0.5425955414, 'val_acc': 0.5141773163, 'noiseless_val_acc': 0.5052915335, 'final_train_acc': 0.5897691083, 'final_val_acc': 0.4981030351, 'final_noiseless_val_acc': 0.4968051118, 'lr': 0.0001, 'depth': 5, 'd_model': 128, 'dropout': 0.1, 'heads': 8, 'd_ffn': 64}, {'  epoch': 2, 'train_loss': 0.7013405201, 'train_acc': 0.5107484076, 'val_acc': 0.5025958466, 'noiseless_val_acc': 0.4968051118, 'final_train_acc': 0.5222929936, 'final_val_acc': 0.5013977636, 'final_noiseless_val_acc': 0.5013977636, 'lr': 0.01, 'depth': 2, 'd_model': 32, 'dropout': 0.1, 'heads': 2, 'd_ffn': 32}, {'  epoch': 36, 'train_loss': 0.6933365255, 'train_acc': 0.5107484076, 'val_acc': 0.5025958466, 'noiseless_val_acc': 0.4968051118, 'final_train_ac ...
# Loading: SAN_sparse_parity_k4_nbits21_n5000_bf20_seed1234
# [{'lr': 0.003981, 'depth': 4, 'd_model': 32, 'dropout': 0.1, 'heads': 8, 'd_ffn': 64, 'epoch': 2, 'train_loss': 0.706175612, 'train_acc': 0.494227707, 'val_acc': 0.5086861022, 'noiseless_val_acc': 0.5086861022}, {'lr': 4e-05, 'depth': 2, 'd_model': 128, 'dropout': 0.05, 'heads': 4, 'd_ffn': 64, 'epoch': 32, 'train_loss': 0.6976875222, 'train_acc': 0.5055732484, 'val_acc': 0.4932108626, 'noiseless_val_acc': 0.4897164537}, {'lr': 0.01, 'depth': 6, 'd_model': 128, 'dropout': 0.1, 'heads': 8, 'd_ffn': 32, 'epoch': 4, 'train_loss': 0.698562097, 'train_acc': 0.494227707, 'val_acc': 0.5086861022, 'noiseless_val_acc': 0.5086861022}, {'lr': 0.0631, 'depth': 4, 'd_model': 16, 'dropout': 0.05, 'heads': 2, 'd_ffn': 128, 'epoch': 4, 'train_loss': 0.7028951895, 'train_acc': 0.494227707, 'val_acc': 0.5086861022, 'noiseless_val_acc': 0.5086861022}, {'lr': 0.001585, 'depth': 1, 'd_model': 32, 'dropout': 0.05, 'heads': 4, 'd_ffn': 128, 'epoch': 3, 'train_loss': 0.6978533082, 'train_acc': 0.4944267516, 'val_acc': 0.5087859425, 'noiseless_val_acc': 0.5087859425}, {'lr': 1.6e-05, 'depth': 4, 'd_model': 32, 'dropout': 0.1, 'heads': 8, 'd_ffn': 32, 'epoch': 3, 'train_loss': 0.7463300164, 'train_acc': 0.5005971338, 'val_acc': 0.5043929712, 'noiseless_val_acc': 0.5082867412}, {'lr': 1e-05, 'depth': 4, 'd_model': 16, 'dropout': 0.05, 'heads': 8, 'd_ffn': 128, 'epoch': 13, 'train_loss': 0.7055832353, 'train_acc': 0.4962181529, 'val_acc': 0.5099840256, 'noiseless_val_acc': 0.5087859425}, {'lr': 0.000398, 'depth': 3, 'd_model': 16, 'dropout': 0.1, 'heads': 4, 'd_ffn': 64, 'epoch': 81, 'train_loss': 0.6921918491, 'train_acc': 0.5340366242, 'val_acc': 0.4991014377, 'noiseless_val_acc': 0.4977036741}, {'lr': 0.000251, 'depth': 5, 'd_model': 32, 'dropout': 0.1, 'heads': 2, 'd_ffn': 128, 'epoch': 1, 'train_loss': 0.7214771946, 'train_acc': 0.4982085987, 'val_acc': 0.5095846645, 'noiseless_val_acc': 0.5078873802}, {'lr': 1.6e-05, 'depth': 4, 'd_model': 16, 'dropout': 0.05, 'heads': 2, 'd_ffn': 64, 'epoch': 4, 'train_loss': 0.7040510159, 'train_acc': 0.4954219745, 'val_acc': 0.5070886581, 'noiseless_val_acc': 0.5068889776}, {'lr': 0.001, 'depth': 4, 'd_model': 32, 'dropout': 0.05, 'heads': 4, 'd_ffn': 128, 'epoch': 6, 'train_loss': 0.6994261719, 'train_acc': 0.4986066879, 'val_acc': 0.5096845048, 'noiseless_val_acc': 0.5072883387}, {'lr': 0.003981, 'depth': 1, 'd_model': 32, 'dropout': 0.1, 'heads': 2, 'd_ffn': 32, 'epoch': 4, 'train_loss': 0.6989260483, 'train_acc': 0.4950238854, 'val_acc': 0.509384984, 'noiseless_val_acc': 0.508586262}, {'lr': 0.003981, 'depth': 1, 'd_model': 32, 'dropout': 0.1, 'heads': 2, 'd_ffn': 64, 'epoch': 4, 'train_loss': 0.6984901087, 'train_acc': 0.4986066879, 'val_acc': 0.5092851438, 'noiseless_val_acc': 0.5099840256}, {'lr': 0.003981, 'depth': 3, 'd_model': 128, 'dropout': 0.05, 'heads': 2, 'd_ffn': 128, 'epoch': 1, 'train_loss': 0.836509388, 'train_acc': 0.494227707, 'val_acc': 0.5086861022, 'noiseless_val_acc': 0.5086861022}, {'lr': 0.002512, 'depth': 6, 'd_model': 64, 'dropout': 0.05, 'heads': 2, 'd_ffn': 64, 'epoch': 3, 'train_loss': 0.7030768535, 'train_acc': 0.494227707, 'val_acc': 0.5086861022, 'noiseless_val_acc': 0.5086861022}, {'lr': 0.01, 'depth': 3, 'd_model': 64, 'dropout': 0.05, 'heads': 4, 'd_ffn': 32, 'epoch': 2, 'train_loss': 0.699840199, 'train_acc': 0.494227707, 'val_acc': 0.5086861022, 'noiseless_val_acc': 0.5086861022}, {'lr': 0.000251, 'depth': 5, 'd_model': 64, 'dropout': 0.1, 'heads': 4, 'd_ffn': 32, 'epoch': 2, 'train_loss': 0.7154594702, 'train_acc': 0.4944267516, 'val_acc': 0.5087859425, 'noiseless_val_acc': 0.5086861022}, {'lr': 0.001585, 'depth': 5, 'd_model': 16, 'dropout': 0.05, 'heads': 2, 'd_ffn': 64, 'epoch': 1, 'train_loss': 0.7115824462, 'train_acc': 0.494227707, 'val_acc': 0.5086861022, 'noiseless_val_acc': 0.5086861022}, {'lr': 0.000158, 'depth': 6, 'd_model': 32, 'dropout': 0.1, 'heads': 2, 'd_ffn': 128, 'epoch': 222, 'train_loss': 0.691633398, 'train_acc': 0.5228901274, 'val_acc': 0.5058905751 ...

# %%
all_H = []
all_mle = []
p_bitflips = [bf / 100 for bf in bf_vals]
def sparity_k4(n_data, n_bits, p_bitflip, seed, subseq_idx=None):
    """Wrapper for sparse_parity_k_n with k=4"""
    return make_datasets.sparse_parity_k_n(n_bits, 4, n_data, p_bitflip, seed, subseq_idx=subseq_idx)

# Generate data with bitflip values
seed = 1234 
n_data = 100000 # ~maximum~ amount of data to analyze
inc = 50000 # increment at which to check convergence
assert inc < n_data
n_bits = 5 # HACK: We only consider the bits that actually contribute to the majority vote
intermediate_idx = list(range(inc, n_data, inc))

all_H = []
all_mle_noisy = []
all_mle_noiseless = []

for i in range(len(p_bitflips)):
    t0 = time.time()
    X, Z, idx = sparity_k4(n_data, n_bits, p_bitflips[i], seed)
    print("generated data for p_bitflip = ", p_bitflips[i], " took ", time.time() - t0, " seconds")
    t0 = time.time()
    # compute the mle performance and the mle lookup table for this dataset
    H_results, mle_results, lookup_results = entropy.empirical_entropy_estimate(Z, intermediate_idx=intermediate_idx)
    print("computed entropy for p_bitflip = ", p_bitflips[i], " took ", time.time() - t0, " seconds")
    all_H.append(H_results)
    all_mle_noisy.append(mle_results)
    # compute the accuracy of MLE(trained on noisy) predicting the noiseless data
    t0 = time.time()
    mle_noiseless = entropy.compute_mle_with_lookup(X, lookup_results[-1])
    print("computed noiseless MLE for p_bitflip = ", p_bitflips[i], " took ", time.time() - t0, " seconds")
    all_mle_noiseless.append(mle_noiseless)
# Out:
# generated data for p_bitflip =  0.0  took  0.6803286075592041  seconds
# computed entropy for p_bitflip =  0.0  took  0.0923621654510498  seconds
# computed noiseless MLE for p_bitflip =  0.0  took  0.20332026481628418  seconds
# generated data for p_bitflip =  0.01  took  0.5541026592254639  seconds
# computed entropy for p_bitflip =  0.01  took  0.09603762626647949  seconds
# computed noiseless MLE for p_bitflip =  0.01  took  0.18886995315551758  seconds
# generated data for p_bitflip =  0.02  took  0.5077998638153076  seconds
# computed entropy for p_bitflip =  0.02  took  0.09223031997680664  seconds
# computed noiseless MLE for p_bitflip =  0.02  took  0.21776652336120605  seconds
# generated data for p_bitflip =  0.05  took  0.5582542419433594  seconds
# computed entropy for p_bitflip =  0.05  took  0.0898885726928711  seconds
# computed noiseless MLE for p_bitflip =  0.05  took  0.19648218154907227  seconds
# generated data for p_bitflip =  0.075  took  0.5552983283996582  seconds
# computed entropy for p_bitflip =  0.075  took  0.10466623306274414  seconds
# computed noiseless MLE for p_bitflip =  0.075  took  0.17606186866760254  seconds
# generated data for p_bitflip =  0.1  took  0.49362611770629883  seconds
# computed entropy for p_bitflip =  0.1  took  0.08799219131469727  seconds
# computed noiseless MLE for p_bitflip =  0.1  took  0.20910382270812988  seconds
# generated data for p_bitflip =  0.125  took  0.514624834060669  seconds
# computed entropy for p_bitflip =  0.125  took  0.09022927284240723  seconds
# computed noiseless MLE for p_bitflip =  0.125  took  0.1972346305847168  seconds
# generated data for p_bitflip =  0.15  took  0.5465495586395264  seconds
# computed entropy for p_bitflip =  0.15  took  0.10110282897949219  seconds
# computed noiseless MLE for p_bitflip =  0.15  took  0.1993565559387207  seconds
# generated data for p_bitflip =  0.175  took  0.5465705394744873  seconds
# computed entropy for p_bitflip =  0.175  took  0.10158157348632812  seconds
# computed noiseless MLE for p_bitflip =  0.175  took  0.17954039573669434  seconds
# generated data for p_bitflip =  0.2  took  0.5344445705413818  seconds
# computed entropy for p_bitflip =  0.2  took  0.10245084762573242  seconds
# computed noiseless MLE for p_bitflip =  0.2  took  0.21660852432250977  seconds

# %%
fig, axes = plt.subplots(1, 1, figsize=(6, 6))
def append_last(x, y):
    # return (x, y) # WARNING
    return np.concatenate((x, [1])).flatten(), np.concatenate((y, [0.5])).flatten()

xvals = np.array([x[-1] for x in all_H])
# xvals = p_bitflips

mle_noisy_final = np.array([x[-1] for x in all_mle_noisy])

rnn_noiseless = np.array(best_dct["RNN"]["noiseless"]).flatten()
rnn_noisy = np.array(best_dct["RNN"]["noisy"]).flatten()
san_noiseless = np.array(best_dct["SAN"]["noiseless"]).flatten()
san_noisy = np.array(best_dct["SAN"]["noisy"]).flatten()

axes.plot(*append_last(xvals, rnn_noisy), label='LSTM', c='r', ls='-')
axes.plot(*append_last(xvals, san_noisy), label='Transformer', c='b', ls='-')
axes.plot(*append_last(xvals, mle_noisy_final), label='Optimal ', c='k', ls='-')

axes.plot(*append_last(xvals, rnn_noiseless), label='LSTM [noiseless]', c='r', ls='--')
axes.plot(*append_last(xvals, san_noiseless), label='Transformer [noiseless]', c='b', ls='--')
axes.plot([0, 1, 1], [1, 1, 0.5], label='Optimal [noiseless]', c='k', ls='--')
# plot the noiseless mle by hand


######
# axes.set_xlim(0, 0.2)

# axes.plot([0, 0.5, 0.5], [1, 1, 0.5], label='MLE [noiseless]', c='k', ls='-')
leg_prop = {'size': 10}
# axes.legend(prop=leg_prop, framealpha=1, bbox_to_anchor=(0.02, 0.02), loc='lower left')
axes.set_xlabel('Next bit entropy')
axes.set_ylabel('Validation accuracy')
axes.set_title('Sparse parity (20, 4)')
print()
# axes.plot(np.repeat(bf_vals, best_n), best_dct["RNN"].flatten(), axis=1, label='RNN')
# axes.plot(np.repeat(bf_vals, best_n), best_dct["SAN"].flatten(), axis=1, label='SAN')

# %%
fig, axes = plt.subplots(1, 1, figsize=(6, 6))
def append_last(x, y):
    # return (x, y) # WARNING
    return np.concatenate((x, [1])).flatten(), np.concatenate((y, [0.5])).flatten()

xvals = np.array([x[-1] for x in all_H])
mle_noisy_final = np.array([x[-1] for x in all_mle_noisy])
# xvals = p_bitflips

rnn_noiseless = np.array(best_dct["RNN"]["noiseless"]).flatten()
rnn_noisy = np.array(best_dct["RNN"]["noisy"]).flatten()
rnn_train = np.array(best_dct["RNN"]["train_acc"]).flatten()
san_noiseless = np.array(best_dct["SAN"]["noiseless"]).flatten()
san_noisy = np.array(best_dct["SAN"]["noisy"]).flatten()
san_train = np.array(best_dct["SAN"]["train_acc"]).flatten()

axes.plot(*append_last(xvals, rnn_noisy), label='LSTM', c='r', ls='-')
axes.plot(*append_last(xvals, san_noisy), label='Transformer', c='b', ls='-')
axes.plot(*append_last(xvals, mle_noisy_final), label='Optimal ', c='k', ls='-')

# axes.plot(*append_last(xvals, rnn_noiseless), label='LSTM [noiseless]', c='r', ls='--')
# axes.plot(*append_last(xvals, san_noiseless), label='Transformer [noiseless]', c='b', ls='--')
# axes.plot([0, 1, 1], [1, 1, 0.5], label='Optimal [noiseless]', c='k', ls='--')
axes.plot(*append_last(xvals, rnn_train), label='LSTM [train]', c='r', ls=':')
axes.plot(*append_last(xvals, san_train), label='Transformer [train]', c='b', ls=':')
# plot the noiseless mle by hand


# axes.plot([0, 0.5, 0.5], [1, 1, 0.5], label='MLE [noiseless]', c='k', ls='-')
leg_prop = {'size': 10}
axes.legend(prop=leg_prop, framealpha=1, bbox_to_anchor=(0.02, 0.02), loc='lower left')
axes.set_xlabel('Next bit entropy')
axes.set_ylabel('Validation accuracy')
axes.set_title('Sparse parity (20, 4)')
print()
# axes.plot(np.repeat(bf_vals, best_n), best_dct["RNN"].flatten(), axis=1, label='RNN')
# axes.plot(np.repeat(bf_vals, best_n), best_dct["SAN"].flatten(), axis=1, label='SAN')

# %% [markdown]
# ### Histogram of training accuracies..?

# %%
plt.close('all')
for bf in bf_vals:
    rnn_df = df_dct["RNN"][bf]
    san_df = df_dct["SAN"][bf]
    # histogram of training accuracies
    fig, axes = plt.subplots(1, 2, figsize=(10, 4))
    train_acc_rnn = rnn_df['train_acc']
    train_acc_san = san_df['train_acc']
    val_acc_rnn = rnn_df['val_acc']
    val_acc_san = san_df['val_acc']
    gen_gap_rnn =  train_acc_rnn - val_acc_rnn
    gen_gap_san =  train_acc_san - val_acc_san


    cts, bins, _ = axes[0].hist(train_acc_rnn, bins='auto', alpha=0.5, label='LSTM', density=True)
    axes[0].hist(train_acc_san, bins=bins, alpha=0.5, label='Transformer', density=True)
    axes[0].legend()
    axes[0].set_title(f"Train, bf={bf}")

    cts, bins, _ = axes[1].hist(val_acc_rnn, bins='auto', alpha=0.5, label='LSTM', density=True)
    axes[1].hist(val_acc_san, bins=bins, alpha=0.5, label='Transformer', density=True)
    axes[1].set_title(f"Val, bf={bf}")
    axes[1].legend()
